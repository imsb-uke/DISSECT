# %% [markdown]
# In this notebook, we shall use a single-cell RNAseq data to deconvolve a bulk RNAseq data **using minimal set of steps**.
#
# This notebook uses the same dataset as in bulkRNAseq.ipynb tutorial.

# %%
import dissect #import DISSECT

# %%
# Get config file and update with required changes

config = dissect.config
config["experiment_folder"] = "tutorial_tldr" # folder to store results
config["simulation_params"]["scdata"] = "data/scRNAseq/sampled_100_data8k.h5ad" #  Path to single cell data
config["simulation_params"]["type"] = "bulk" # Type of simulation. bulk or ST
config["simulation_params"]["celltype_col"] = "cell_type" # Cell type column name in .obs of single-cell data
config["deconv_params"]["test_dataset"] = "data/bulkRNAseq/bulk_gse120502.txt"

# %%
# run dissect
dissect.run_dissect(config)
# Out:
# Number of batches in single-cell data is 1.
# 100%|███████████████████████████████████████████████████████████████████████████| 6000/6000 [02:34<00:00, 38.89it/s]
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~/miniconda/envs/dissect/lib/python3.9/site-packages/anndata/_io/utils.py:214, in report_write_key_on_error.<locals>.func_wrapper(elem, key, val, *args, **kwargs)
#     213 try:
# --> 214     return func(elem, key, val, *args, **kwargs)
#     215 except Exception as e:
#
# File ~/miniconda/envs/dissect/lib/python3.9/site-packages/anndata/_io/specs/registry.py:175, in write_elem(f, k, elem, modifiers, *args, **kwargs)
#     174 else:
# --> 175     _REGISTRY.get_writer(dest_type, t, modifiers)(f, k, elem, *args, **kwargs)
#
# File ~/miniconda/envs/dissect/lib/python3.9/site-packages/anndata/_io/specs/registry.py:24, in write_spec.<locals>.decorator.<locals>.wrapper(g, k, *args, **kwargs)
#      22 @wraps(func)
#      23 def wrapper(g, k, *args, **kwargs):
# ---> 24     result = func(g, k, *args, **kwargs)
#      25     g[k].attrs.setdefault("encoding-type", spec.encoding_type)
#
# File ~/miniconda/envs/dissect/lib/python3.9/site-packages/anndata/_io/specs/methods.py:307, in write_basic(f, k, elem, dataset_kwargs)
#     306 """Write methods which underlying library handles nativley."""
# --> 307 f.create_dataset(k, data=elem, **dataset_kwargs)
#
# File ~/miniconda/envs/dissect/lib/python3.9/site-packages/h5py/_hl/group.py:149, in Group.create_dataset(self, name, shape, dtype, data, **kwds)
#     147         group = self.require_group(parent_path)
# --> 149 dsid = dataset.make_new_dset(group, shape, dtype, data, name, **kwds)
#     150 dset = dataset.Dataset(dsid)
#
# File ~/miniconda/envs/dissect/lib/python3.9/site-packages/h5py/_hl/dataset.py:145, in make_new_dset(parent, shape, dtype, data, name, chunks, compression, shuffle, fletcher32, maxshape, compression_opts, fillvalue, scaleoffset, track_times, external, track_order, dcpl, allow_unknown_filter)
#     144 if (data is not None) and (not isinstance(data, Empty)):
# --> 145     dset_id.write(h5s.ALL, h5s.ALL, data)
#     147 return dset_id
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5d.pyx:232, in h5py.h5d.DatasetID.write()
#
# File h5py/_proxy.pyx:114, in h5py._proxy.dset_rw()
#
# OSError: [Errno 28] Can't write data (file write failed: time = Sat Jan 13 15:50:51 2024
# , filename = 'tutorial_tldr/simulation/simulated.h5ad', file descriptor = 57, errno = 28, error message = 'No space left on device', buf = 0x7f262d75eac0, total write size = 40026640, bytes this sub-write = 40026640, bytes actually written = 18446744073709551615, offset = 0)
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# File ~/miniconda/envs/dissect/lib/python3.9/site-packages/anndata/_io/h5ad.py:104, in write_h5ad(filepath, adata, force_dense, as_dense, dataset_kwargs, **kwargs)
#     103 write_elem(f, "varp", dict(adata.varp), dataset_kwargs=dataset_kwargs)
# --> 104 write_elem(f, "layers", dict(adata.layers), dataset_kwargs=dataset_kwargs)
#     105 write_elem(f, "uns", dict(adata.uns), dataset_kwargs=dataset_kwargs)
#
# File ~/miniconda/envs/dissect/lib/python3.9/site-packages/anndata/_io/utils.py:214, in report_write_key_on_error.<locals>.func_wrapper(elem, key, val, *args, **kwargs)
#     213 try:
# --> 214     return func(elem, key, val, *args, **kwargs)
#     215 except Exception as e:
#
# File ~/miniconda/envs/dissect/lib/python3.9/site-packages/anndata/_io/specs/registry.py:175, in write_elem(f, k, elem, modifiers, *args, **kwargs)
#     174 else:
# --> 175     _REGISTRY.get_writer(dest_type, t, modifiers)(f, k, elem, *args, **kwargs)
#
# File ~/miniconda/envs/dissect/lib/python3.9/site-packages/anndata/_io/specs/registry.py:24, in write_spec.<locals>.decorator.<locals>.wrapper(g, k, *args, **kwargs)
#      22 @wraps(func)
#      23 def wrapper(g, k, *args, **kwargs):
# ---> 24     result = func(g, k, *args, **kwargs)
#      25     g[k].attrs.setdefault("encoding-type", spec.encoding_type)
#
# File ~/miniconda/envs/dissect/lib/python3.9/site-packages/anndata/_io/specs/methods.py:281, in write_mapping(f, k, v, dataset_kwargs)
#     280 for sub_k, sub_v in v.items():
# --> 281     write_elem(g, sub_k, sub_v, dataset_kwargs=dataset_kwargs)
#
# File ~/miniconda/envs/dissect/lib/python3.9/site-packages/anndata/_io/utils.py:220, in report_write_key_on_error.<locals>.func_wrapper(elem, key, val, *args, **kwargs)
#     219 parent = _get_parent(elem)
# --> 220 raise type(e)(
#     221     f"{e}\n\n"
#     222     f"Above error raised while writing key {key!r} of {type(elem)} "
#     223     f"to {parent}"
#     224 ) from e
#
# OSError: [Errno 28] Can't write data (file write failed: time = Sat Jan 13 15:50:51 2024
# , filename = 'tutorial_tldr/simulation/simulated.h5ad', file descriptor = 57, errno = 28, error message = 'No space left on device', buf = 0x7f262d75eac0, total write size = 40026640, bytes this sub-write = 40026640, bytes actually written = 18446744073709551615, offset = 0)
#
# Above error raised while writing key 'Bcells' of <class 'h5py._hl.group.Group'> to /
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# Cell In[3], line 2
#       1 # run dissect
# ----> 2 dissect.run_dissect(config)
#
# File ~/miniconda/envs/dissect/lib/python3.9/site-packages/dissect/deconv.py:7, in run_dissect(config)
#       6 def run_dissect(config):
# ----> 7         simulate(config)
#       8         dataset(config)
#       9         run_dissect_frac(config)
#
# File dissect/PropsSimulator/simulator.pyx:614, in dissect.PropsSimulator.simulator.simulate()
#
# File dissect/PropsSimulator/simulator.pyx:200, in dissect.PropsSimulator.simulator.Simulate.simulate()
#
# File ~/miniconda/envs/dissect/lib/python3.9/site-packages/anndata/_core/anndata.py:1918, in AnnData.write_h5ad(self, filename, compression, compression_opts, force_dense, as_dense)
#    1915 if filename is None:
#    1916     filename = self.filename
# -> 1918 _write_h5ad(
#    1919     Path(filename),
#    1920     self,
#    1921     compression=compression,
#    1922     compression_opts=compression_opts,
#    1923     force_dense=force_dense,
#    1924     as_dense=as_dense,
#    1925 )
#    1927 if self.isbacked:
#    1928     self.file.filename = filename
#
# File ~/miniconda/envs/dissect/lib/python3.9/site-packages/anndata/_io/h5ad.py:105, in write_h5ad(filepath, adata, force_dense, as_dense, dataset_kwargs, **kwargs)
#     103 write_elem(f, "varp", dict(adata.varp), dataset_kwargs=dataset_kwargs)
#     104 write_elem(f, "layers", dict(adata.layers), dataset_kwargs=dataset_kwargs)
# --> 105 write_elem(f, "uns", dict(adata.uns), dataset_kwargs=dataset_kwargs)
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File ~/miniconda/envs/dissect/lib/python3.9/site-packages/h5py/_hl/files.py:544, in File.__exit__(self, *args)
#     541 @with_phil
#     542 def __exit__(self, *args):
#     543     if self.id:
# --> 544         self.close()
#
# File ~/miniconda/envs/dissect/lib/python3.9/site-packages/h5py/_hl/files.py:526, in File.close(self)
#     520 if self.id.valid:
#     521     # We have to explicitly murder all open objects related to the file
#     522
#     523     # Close file-resident objects first, then the files.
#     524     # Otherwise we get errors in MPI mode.
#     525     self.id._close_open_objects(h5f.OBJ_LOCAL | ~h5f.OBJ_FILE)
# --> 526     self.id._close_open_objects(h5f.OBJ_LOCAL | h5f.OBJ_FILE)
#     528     self.id.close()
#     529     _objects.nonlocal_close()
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5f.pyx:358, in h5py.h5f.FileID._close_open_objects()
#
# OSError: [Errno 28] Can't close file (file write failed: time = Sat Jan 13 15:50:51 2024
# , filename = 'tutorial_tldr/simulation/simulated.h5ad', file descriptor = 57, errno = 28, error message = 'No space left on device', buf = 0x5598a33058c0, total write size = 62400, bytes this sub-write = 62400, bytes actually written = 18446744073709551615, offset = 0)
